# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
  

driver = webdriver.Chrome(executable_path='C:\\Users\\Moyez\\AppData\\Local\\Programs\\Python\\Python37-32\\chromedriver_win32\\chromedriver.exe')
driver.get('https://elearn.daffodilvarsity.edu.bd/login/index.php')


time.sleep(2)
username = 'maruf.swe'
password = 'asdf1234Z@'
time.sleep(2)
driver.find_element_by_name('username').send_keys(username)
driver.find_element_by_name('password').send_keys(password)

time.sleep(2)
driver.find_element_by_id('loginbtn').click()

time.sleep(1)
for i in range(2, 6):
    time.sleep(1)
    driver.get('https://elearn.daffodilvarsity.edu.bd/course/index.php?mycourses=1')
    try: 
        time.sleep(2)
        driver.find_element_by_xpath('/html/body/div[3]/div[2]/div[3]/div/div/section[2]/div/div[2]/div/div[2]/div[1]/div[' + str(i) + ']').click()
        course_url = driver.current_url
        time.sleep(2)
        forum_list = []
        forum_link = []
        forum_list = driver.find_elements_by_partial_link_text('Forum')
        for forum in forum_list:
            link = forum.get_attribute('href')
            forum_link.append(forum.get_attribute('href'))
        for i in range(2, len(forum_link)):
            driver.get(forum_link[i])
            time.sleep(1)
            for i in range(1, 20):
                try:
                    time.sleep(1)
                    driver.find_element_by_xpath('/html/body/div[3]/div[2]/div[3]/div/div/section[2]/div/div[2]/div[2]/table/tbody/tr[' + str(i) +']/th/div/a').click()
                    for j in range(0, 50):
                        try:
                            time.sleep(1)
                            driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[3]/div/div/section[2]/div/div[1]/div/article/div[2]/article[' + str(j) +']/div[1]/div/div/div[2]/div[2]/div/a[6]').click()
                            time.sleep(1)
                            driver.find_element_by_name('post').send_keys('Appreciate')
                            time.sleep(1)
                            #driver.find_element_by_xpath('/html/body/div[3]/div[2]/div[3]/div/div/section[2]/div/div[1]/div/article/div[2]/article[' + str(j) +']/div[1]/div/div[2]/div/form/div[2]/button[1]')
                            time.sleep(1)
                            driver.refresh()
                            time.sleep(1)
                        except:
                            continue
                except:
                    break

    except:
        break

# %%
time.sleep(1)
for i in range(2, 5):
    time.sleep(1)
    driver.get('https://elearn.daffodilvarsity.edu.bd/course/index.php?mycourses=1')
    try: 
        time.sleep(2)
        driver.find_element_by_xpath('/html/body/div[3]/div[2]/div[3]/div/div/section[2]/div/div[2]/div/div[2]/div[1]/div[' + str(i) + ']').click()
        course_url = driver.current_url
        time.sleep(2)
        forum_list = []
        forum_link = []
        forum_list = driver.find_elements_by_partial_link_text('Forum')
        for forum in forum_list:
            link = forum.get_attribute('href')
            forum_link.append(forum.get_attribute('href'))
        for i in range(2, len(forum_link)):
            driver.get(forum_link[i])
            time.sleep(1)
            for i in range(1, 15):
                try:
                    time.sleep(1)
                    driver.find_element_by_xpath('/html/body/div[3]/div[2]/div[3]/div/div/section[2]/div/div[2]/div[2]/table/tbody/tr[' + str(i) +']/th/div/a').click()
                    for j in range(0, 50):
                        try:
                            time.sleep(1)
                            driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[3]/div/div/section[2]/div/div[1]/div/article/div[2]/article[' + str(j) +']/div[1]/div/div/div[2]/div[2]/div/a[6]').click()
                            time.sleep(1)
                            driver.find_element_by_name('post').send_keys('Appreciate')
                            time.sleep(1)
                            #driver.find_element_by_xpath('/html/body/div[3]/div[2]/div[3]/div/div/section[2]/div/div[1]/div/article/div[2]/article[' + str(j) +']/div[1]/div/div[2]/div/form/div[2]/button[1]')
                            time.sleep(1)
                            driver.refresh()
                            time.sleep(1)
                        except:
                            continue
                except:
                    break

    except:
        break

# %%
for j in range(0, 105):
    try:
        time.sleep(2)
        driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[3]/div/div/section[2]/div/div[1]/div/article/div[2]/article[' + str(j) +']/div[1]/div/div/div[2]/div[2]/div/a[6]').click()
        time.sleep(1)
        driver.find_element_by_name('post').send_keys('Appreciate')
        time.sleep(1)
        driver.find_element_by_xpath('/html/body/div[3]/div[2]/div[3]/div/div/section[2]/div/div[1]/div/article/div[2]/article[' + str(j) +']/div[1]/div/div[2]/div/form/div[2]/button[1]').click()
        time.sleep(1)
        driver.refresh()
    except:
        continue
